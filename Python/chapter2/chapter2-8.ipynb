# %% [markdown]
# ### 자료형 종류
# 1. int(integer) : 정수
# 2. float(float) : 실수
# 3. str : 문자열
# 4. bool : 참, 거짓(true, false) 1, 0
# ---
#
# 5. list
# 6. tuple
# 7. dict
# 8. set

# %%
# bool의 쇼타임
# 주의할점 True <_x_> true / False <_x_> false
# 부등호
3 != 3
# Out:
# False

# %%
# 문자열 비교
"python" == "Python"
"Python" == "Python"
"Python" != 'python'
# Out:
# True

# %%
# 중요
# ==, is
3 is 3
3 == 3

3.0 is 3
3.0 == 3

print(id(3.0))
print(id(3))
# Out:
# 136060910703952
# 136061351477552
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:6: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:6: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-24-4a610bdd2952>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   3 is 3
# <ipython-input-24-4a610bdd2952>:6: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   3.0 is 3

# %% [markdown]
# 미션: 값 비교에는 is를 쓰면 안되는데 그 이유를 찾아서 기술 블로그에 작성해보세요
#
# is는 두 객체의 식별을 비교한다. 두 객체가 동일한 메모리에 저장되어 있는지를 확인한다.
# == 비교는 두 객체의 내용을 비교한다. 두 객체의 데이터가 동일한지 확인한다.

# %%
#본격적인 논리연사자
# True : 1 / False : 0
#True and True
True and False
#False and True
#False and False
# and : 둘을 비교했을때 동일하다면 True를 반환, 동일하지 않다면 후자를 반환
# Out:
# False

# %%
True or True
True or False
False or True
False or False
# or : 둘 중 하나만 True라도 True를 반환
# Out:
# False

# %%
not True
not False
# not : 부정
# Out:
# True

# %%
#10 == 12 or 6 != 2
2 > 5 and 7 == 7
#not 14 <= 15
#not 7 is 7.0
# Out:
# False

# %%
#문자열? true?

bool("힘들어요 여러분")
# Out:
# True

# %%
# 굉장히 중요한 내용 !
# 단락 평가
print(False and True)
print(False and "힘들어요")
print(False or True)
print(False or "힘들어요")
print(True and "힘들어요")
print(True or "힘들어요")
print("힘들어요" and True)
print("힘들어요" or True)
# Out:
# False
# False
# True
# 힘들어요
# 힘들어요
# True
# True
# 힘들어요
