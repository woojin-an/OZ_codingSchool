# %% [markdown]
# ##시퀀스 자료형
# * 문자열 :
#     * 시퀀스형에서 사용할 수 있는 메소드(count(), index(), split() 등)
#     * 슬라이싱 ([:],[::])
#     * 요소들로 이루어져 가능했던 기능들 (요소합치기, 요소 찾기 등)
# * list :
#     * 시퀀스형에서 사용할 수 있는 메소드 (count(), index(), split() 등)
#     * 슬라이싱 ([:],[::])
#     * 요소들로 이루어져 가능했던 기능들 (요소합치기, 요소 찾기 등)
#     * list 지원하는 다양한 메소드 (append(), insert(), del, sort(), reverse() 등)
# * tuple :
#     * 리스트처럼 요소를 일렬로 저장하지만 안에 저장된 요소를 변경, 추가, 삭제할 수 없다.
#     * 값을 추가, 삭제, 변경할 수 없기 때문에 사용하지 못하는 메소드가 많음
#     * tuple의 생성 방법: tuple= 값, 값,,, 또는 tuple = (값, 값 ,,,,)
#
# * dict(딕셔너리)
#     * list, tuple, str, range(범위안에 연속된 데이터를 만드는 시퀀스)
#     공통적인 특징: 데이터의 연관성이 없음
#     * dict: 여러개의 값이 일렬로 정렬되면서도 값끼리의 연관성이 존재
#     (예시: 게임 캐릭터의 힘30, 지능20, 체력40, 민첩90)
#     * dict 생성방법 : 중괄호
#
# * set
#     * set은 수학의 집합을 의미함.
#     * 딕셔너리와 같이 순서가 없음
#     * 값의 중복을 허락하지 않음
#     * set의 생성 방법도 중괄호

# %%
# list [], tuple(), dict{}

짱짱맨 = {"힘":30, "지능":20, "체력":40, "민첩":90}
짱짱맨

# {키 : 값}
# {key1:value1, key2:value2}

# 시퀀스 데이터는 인덱승을 이용해 데이터를 찾았음.

# 짱짱맨[1]
짱짱맨["힘"]
print(f'짱짱맨님은 힘이 {짱짱맨["힘"]}입니다.')
# Out:
# 짱짱맨님은 힘이 30입니다.

# %%
#빈 딕셔너리 만들기
딕셔너리 = {}
딕셔너리

딕셔너리2 = dict()
딕셔너리2

#값을 넣어 만드는 방법
#dict()로 생성시 값 넣는 기호 "", : 주의해야함
딕셔너리3 = dict(힘=30, 지능=20, 체력=40, 민첩=90)
딕셔너리3

# zip(): 병렬처리를 도와줍니다.
딕셔너리4= dict(zip(["힘","지능","체력","민첩"],[30,20,40,90]))
딕셔너리4

# 값의 중복은 허락되는데, 키의 중복은 허락되지 않음
짱짱맨 = {"힘":30, "지능":20, "체력":40, "민첩":90, "힘":40, "지구력":90}
짱짱맨 #중복될 경우 가장 나중에 나온 값이 키에 적용됨
# Out:
# {'힘': 40, '지능': 20, '체력': 40, '민첩': 90, '지구력': 90}

# %%
#딕셔너리의 다양한 메소드
print(짱짱맨.keys())
print(짱짱맨.values())
print(짱짱맨.items())
print(짱짱맨)

리스트화된_짱짱맨 = list(짱짱맨.items())
print(리스트화된_짱짱맨[1][1])
# Out:
# dict_keys(['힘', '지능', '체력', '민첩', '지구력'])
# dict_values([40, 20, 40, 90, 90])
# dict_items([('힘', 40), ('지능', 20), ('체력', 40), ('민첩', 90), ('지구력', 90)])
# {'힘': 40, '지능': 20, '체력': 40, '민첩': 90, '지구력': 90}
# 20

# %%
#딕셔너리값 추가, 삭제, 변경
짱짱맨

#삭제
#del 짱짱맨["지구력"]
#짱짱맨

#변경
#짱짱맨["지능"] = 100
#짱짱맨

#추가
짱짱맨.update({"손재주":44, "매력":100})
짱짱맨
# Out:
# {'힘': 40, '지능': 100, '체력': 40, '민첩': 90, '손재주': 44, '매력': 100}

# %%
코디 = {
"모자": {
        "캡": "발렌시아",
        "비니": "셀린느"
    },
    "상의": {
        "후드티" : "칼하트",
        "맨투맨" : "슈프림"
    }
}

코디
코디["모자"]
코디["모자"]["캡"]
# Out:
# '발렌시아'

# %%
* 해시, 해시맵, 해시테이블

# %%
# dict
주문_개수 = map(int, input(f'붕어빵(팥), 붕어빵(슈크림), 붕어빵(잡채)를 순서대로 개수를 입력하고 안사는 붕어빵에는 0 입력').split(','))

품목별_가격 = {"팥": 2000, "슈크림": 2500, "잡채": 3000}

#
주문_개수 = list(주문_개수)
총_주문_개수 = sum(주문_개수)
total = 0

total += 품목별_가격["팥"] * 주문_개수[0]
total += 품목별_가격["슈크림"] * 주문_개수[1]
total += 품목별_가격["잡채"] * 주문_개수[2]

print(f'주문이 완료되었습니다. 팥 {주문_개수[0]}개, 슈크림 {주문_개수[1]}개, 잡채 {주문_개수[2]}개, 총 {총_주문_개수}개 결제 금액은 {total}원 입니다.')
# Out:
# 붕어빵(팥), 붕어빵(슈크림), 붕어빵(잡채)를 순서대로 개수를 입력하고 안사는 붕어빵에는 0 입력2,3,0
# 주문이 완료되었습니다. 팥 2개, 슈크림 3개, 잡채 0개, 총 5개 결제 금액은 11500원 입니다.

# %%
채소 = {"당근", "배추", "대파", "양파"}
type(채소)

#순서가 없고, 출력하면 요소가 다르게 나옴

print(채소)

#세트를 만드는 다양한 방법

# 세트 = set()
# 세트
# 세트2 = {}
# 세트2
# Out:
# {'양파', '당근', '배추', '대파'}
# {}

# %%
#중복이 안됨
사과_리스트 = list("apple")
print(사과_리스트)
사과_튜플 = tuple("apple")
print(사과_튜플)
사과_set = set("apple")
print(사과_set)
# Out:
# ['a', 'p', 'p', 'l', 'e']
# ('a', 'p', 'p', 'l', 'e')
# {'a', 'e', 'l', 'p'}

# %%
# set() 자료형의 데이터 추가, 삭제, 변경


#set() 함수의 데이터 삽입
# 채소.add("토마토")
# 채소

# 채소.update("깻잎")
# 채소

# #set() 함수의 데이터 삭제
# 채소.remove("잎")
# 채소
# 채소.discard("잎")
# 채소

# 채소.pop()
# 채소

# 채소.pop()
# 채소

# %%
#set = 집합, 합집합, 교집합, 차집합 기타 등등
# 대표적으로 합집합, 교집합, 차집합

채소1 = {"당근", "양파", "오이", "배추"}
채소2 = {"양파", "오이", "대파", "가지"}

#합집합 (union)
채소1 | 채소2
set.union(채소1, 채소2)

#교집합 (intersection)
채소1 & 채소2
set.intersection(채소1, 채소2)

#차집합 (difference)
채소1 - 채소2
set.difference(채소1, 채소2)
# Out:
# {'당근', '배추'}
# {'당근', '배추'}
