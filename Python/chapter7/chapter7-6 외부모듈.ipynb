# %% [markdown]
# [외부모듈]
# 파이썬의 장점 중 하나는 다양한 외부모듈
#
# 인공지능 분야에서는 텐서플로와 사이킷런, 웹분야에서는 django와 fastapi 등 굉장이 많은 모듈이 존재
#
# 이러한 모듈을 설치하는 방법은 pip install 이라는 명령어 실행
#
# `pip install 모듈 이름`
#
# (package installer of Python)
#
# 파이썬 외부모듈중 정적페이지를 크롤링하거나 스크래핑할때 사용하는 beautifulsoup4 설치, 사용
#
# beautifulsoup4 공식 홈페이지: https://www.crummy.com/software/BeautifulSoup/bs4/doc.ko/
#
# [Mac]
# pip3 install beautifulsoup4
# brew install beautifulsoup4
#
# [기상청 RSS 서비스] https://www.weather.go.kr/w/pop/rss-guide.do
#
# rss 전국 기상 정보 주소: https://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108

# %%
from urllib import request
from bs4 import BeautifulSoup

target = request.urlopen("https://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108")

soup = BeautifulSoup(target, "html.parser")

for location in soup.select("location"):
    print("도시:", location.select_one("city").string)
    print("날씨:", location.select_one("wf").string)
    print("최저기온:", location.select_one("tmn").string)
    print("최고기온:", location.select_one("tmx").string)
    print()
# Out:
# 도시: 서울
# 날씨: 흐리고 비
# 최저기온: 24
# 최고기온: 28
#
# 도시: 인천
# 날씨: 흐리고 비
# 최저기온: 23
# 최고기온: 27
#
# 도시: 수원
# 날씨: 흐리고 비
# 최저기온: 23
# 최고기온: 29
#
# 도시: 파주
# 날씨: 흐리고 비
# 최저기온: 21
# 최고기온: 28
#
# 도시: 이천
# 날씨: 흐리고 비
# 최저기온: 23
# 최고기온: 28
#
# 도시: 평택
# 날씨: 흐리고 비
# 최저기온: 24
# 최고기온: 30
#
# 도시: 춘천
# 날씨: 흐리고 비
# 최저기온: 22
# 최고기온: 28
#
# 도시: 원주
# 날씨: 흐리고 비
# 최저기온: 24
# 최고기온: 28
#
# 도시: 강릉
# 날씨: 흐리고 비
# 최저기온: 25
# 최고기온: 31
#
# 도시: 대전
# 날씨: 흐리고 비
# 최저기온: 24
# 최고기온: 30
#
# 도시: 세종
# 날씨: 흐리고 비
# 최저기온: 23
# 최고기온: 29
#
# 도시: 홍성
# 날씨: 흐리고 비
# 최저기온: 24
# 최고기온: 28
#
# 도시: 청주
# 날씨: 흐리고 비
# 최저기온: 25
# 최고기온: 31
#
# 도시: 충주
# 날씨: 흐리고 비
# 최저기온: 23
# 최고기온: 30
#
# 도시: 영동
# 날씨: 흐리고 비
# 최저기온: 23
# 최고기온: 31
#
# 도시: 광주
# 날씨: 흐리고 비
# 최저기온: 25
# 최고기온: 31
#
# 도시: 목포
# 날씨: 흐리고 비
# 최저기온: 25
# 최고기온: 29
#
# 도시: 여수
# 날씨: 흐리고 비
# 최저기온: 24
# 최고기온: 27
#
# 도시: 순천
# 날씨: 흐리고 비
# 최저기온: 24
# 최고기온: 30
#
# 도시: 광양
# 날씨: 흐리고 비
# 최저기온: 24
# 최고기온: 31
#
# 도시: 나주
# 날씨: 흐리고 비
# 최저기온: 24
# 최고기온: 30
#
# 도시: 전주
# 날씨: 흐리고 비
# 최저기온: 25
# 최고기온: 31
#
# 도시: 군산
# ...
