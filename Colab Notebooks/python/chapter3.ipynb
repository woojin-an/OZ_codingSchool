# %%
# 주석은 이렇게 하는 것이다
print("진짜 안보일까?")
print("안보이는군")
# Out:
# 진짜 안보일까?
# 안보이는군

# %%
# print("진짜 안보일까?")
# print("안보이는군")

# %%
for 동물 in ("토끼", "사자", "푸바오", "호랑이"):
    print(동물)
    print("보러 갈래요?")
# Out:
# 토끼
# 보러 갈래요?
# 사자
# 보러 갈래요?
# 푸바오
# 보러 갈래요?
# 호랑이
# 보러 갈래요?
